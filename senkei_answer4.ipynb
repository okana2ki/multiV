# %% [markdown]
# <a href="https://colab.research.google.com/github/okana2ki/multiV/blob/main/senkei_answer4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# このノートブックは、以下からダウンロードしたものを改変したものです：
#
# [高等学校における「情報II」のためのデータサイエンス・データ解析入門](https://www.stat.go.jp/teacher/comp-learn-04.html)（総務省統計局）

# %% [markdown]
# # 1.線形回帰

# %% [markdown]
# ## ライブラリーのインポート

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## データの読み込み

# %% [markdown]
# データ内容は以下の通りです。
#
# ID：ID
# sales：売上個数
# insta_post：Instagram投稿数
# insta_good：Instagramいいね！数
# flyer：チラシ配布枚数
# event：イベントあり＝１、イベントなし＝０
# new_item：新作発売日＝１
# holiday：土日祝＝１

# %%
df = pd.read_csv("senkei.csv", index_col=0)  # ← データファイルのパスを正しく指定して下さい。
df.head()
# Out:
#     sales  insta_post  insta_good  flyer  event  new_item  holiday
# ID
# 1      62           0          20      0      0         0        0
# 2      60           0          24      0      0         0        0
# 3     104           0          26      0      0         0        0
# 4     102           0          22      0      0         0        0
# 5     178           0          39      0      0         0        1

# %% [markdown]
# ↑Colab AIが次のステップとして提案してきた「Generate code with df」や「View recommended plots」をクリックしてみよう！

# %%
# dfのサイズを表示
df.shape
# Out:
# (53, 7)

# %% [markdown]
# ## 単回帰分析

# %% [markdown]
# 説明変数をinsta_good、目的変数をsalesとして、単回帰分析を行います。

# %%
# 説明変数insta_good
X = df.iloc[:, 2].values  # ← Colab AIで教えてもらおう
X = X.reshape(-1,1)  # reshapeでどのような変換をしているか？なぜそれが必要か？Colab AIに尋ねてみましょう

# 目的変数sales
Y = df.iloc[:, 0].values

# %% [markdown]
# 以下のプログラムもColab AIで教えてもらおう

# %%
# sklearn.linear_model.LinearRegression クラスを読み込み
from sklearn import linear_model
clf = linear_model.LinearRegression()

# 予測モデルを作成
clf.fit(X, Y)

# 回帰係数
print(clf.coef_)

# 切片
print(clf.intercept_)

# 決定係数
print(clf.score(X, Y))
# Out:
# [2.05852128]
# 101.71515440413765
# 0.5218980221448157

# %% [markdown]
# insta_goodの回帰係数と、単回帰の式の切片が分かりました。
# 決定係数は、0～1の範囲の値をとり、値が大きいほどモデルが適切にデータを表現できているといえます。

# %% [markdown]
# 対応する散布図を作成し、回帰直線を描き加えてみましょう。

# %%
# prompt: salesとinsta_goodの散布図を作成し、単回帰分析の回帰式を散布図に書き加えて下さい。

# 散布図を作成
plt.scatter(X, Y)

# 回帰直線を作成
x_min, x_max = X.min(), X.max()
y_min = clf.predict([[x_min]])
y_max = clf.predict([[x_max]])

# 回帰直線を散布図に追加
plt.plot([x_min, x_max], [y_min, y_max], color="r")

# 回帰式の切片と回帰係数を散布図に書き加える
plt.text(x_min, y_min, f"y = {clf.coef_[0]:.3f}x + {clf.intercept_:.3f}", fontsize=12)

# グラフのタイトルとラベルを設定
plt.title("Sales vs. Instagram Likes")
plt.xlabel("Instagram Likes")
plt.ylabel("Sales")

# グラフを表示
plt.show()

# %% [markdown]
# ## 重回帰分析

# %% [markdown]
# insta_post以降6カラムを説明変数、目的変数をsalesとして、重回帰分析を行います。

# %%
# 説明変数
X = df.iloc[:, 1:7].values

# 目的変数
Y = df.iloc[:, 0].values

# %%
# sklearn.linear_model.LinearRegression クラスを読み込み
from sklearn import linear_model
clf = linear_model.LinearRegression()

# 予測モデルを作成
clf.fit(X, Y)

# 偏回帰係数
df_except_sales = df.iloc[:, 1:7]
print(pd.DataFrame({"Name":df_except_sales.columns,
                    "Coefficients":clf.coef_}))

# 切片
print(clf.intercept_)
# Out:
#          Name  Coefficients
# 0  insta_post     48.871107
# 1  insta_good      0.684993
# 2       flyer      0.206098
# 3       event    245.436745
# 4    new_item    -38.905751
# 5     holiday     26.549665
# 131.89410662096918

# %% [markdown]
# 各変数の偏回帰係数と重回帰の式の切片が分かりました。

# %% [markdown]
# ### 標準化
# 各変数がどの程度目的変数に影響しているかを**比較**する（**他の変数と比べて**どれくらい影響しているかを知る）には、各変数を**標準化**（平均を0、分散を1に揃える）します。

# %%
# データフレームの各列を標準化
df2 = df.apply(lambda x: (x - np.mean(x)) / np.std(x))
df2.head()
# Out:
#        sales  insta_post  insta_good     flyer     event  new_item   holiday
# ID
# 1  -1.427147   -0.322749   -0.839503 -0.511766 -0.138675  -0.19803 -0.657596
# 2  -1.447439   -0.322749   -0.723860 -0.511766 -0.138675  -0.19803 -0.657596
# 3  -1.001013   -0.322749   -0.666038 -0.511766 -0.138675  -0.19803 -0.657596
# 4  -1.021305   -0.322749   -0.781681 -0.511766 -0.138675  -0.19803 -0.657596
# 5  -0.250205   -0.322749   -0.290198 -0.511766 -0.138675  -0.19803  1.520691

# %%
# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# %%
# sklearn.linear_model.LinearRegression クラスを読み込み
from sklearn import linear_model
clf = linear_model.LinearRegression()

# 予測モデルを作成
clf.fit(X, Y)

# 標準化偏回帰係数
df2_except_sales = df2.iloc[:, 1:7]
print(pd.DataFrame({"Name":df2_except_sales.columns,
                    "Coefficients":clf.coef_}))

# 切片
print(clf.intercept_)
# Out:
#          Name  Coefficients
# 0  insta_post      0.144937
# 1  insta_good      0.240394
# 2       flyer      0.424020
# 3       event      0.338815
# 4    new_item     -0.075220
# 5     holiday      0.123663
# 2.5844842985983608e-17

# %% [markdown]
# ↑標準化後の各変数の偏回帰係数と重回帰の式の切片が分かりました。
#
# ↓**標準化偏回帰係数の絶対値**によって、売上個数への**各変数の相対的な影響の強さ**を確認することができます。

# %%
# 標準化偏回帰係数の絶対値をとって昇順にソート
df2_except_sales = df2.iloc[:, 1:7]
print(pd.DataFrame({"Name":df2_except_sales.columns,
                    "Coefficients":np.abs(clf.coef_)}).sort_values(by='Coefficients'))

# 切片
print(clf.intercept_)
# Out:
#          Name  Coefficients
# 4    new_item      0.075220
# 5     holiday      0.123663
# 0  insta_post      0.144937
# 1  insta_good      0.240394
# 3       event      0.338815
# 2       flyer      0.424020
# 2.5844842985983608e-17

# %% [markdown]
# ### 学習用データとテストデータ

# %% [markdown]
# 学習用データとテストデータを用いて、線形回帰（重回帰分析）を行います。
# 先程、標準化したデータを使います。

# %%
# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# 学習用データとテスト用データを7:3に分割する；ランダム性あり
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
# 予測モデルを作成
model = linear_model.LinearRegression()
model.fit(X_train, Y_train)

# 標準化偏回帰係数
df2_except_sales = df2.iloc[:, 1:7]
print(pd.DataFrame({"Name":df2_except_sales.columns,
                    "Coefficients":clf.coef_}))

# 切片
print(model.intercept_)
# Out:
#          Name  Coefficients
# 0  insta_post      0.144937
# 1  insta_good      0.240394
# 2       flyer      0.424020
# 3       event      0.338815
# 4    new_item     -0.075220
# 5     holiday      0.123663
# 0.00660070034182364

# %% [markdown]
# 学習データにおける各変数の標準化偏回帰係数と重回帰の式の切片が分かりました。

# %% [markdown]
# ### 平均二乗誤差
# 訓練データとテストデータのそれぞれに対して、予測値と実測値の平均二乗誤差を求めます。**データの分割時にランダム性があるため、分割をやり直し、その分割で改めて学習すると、そのたびに平均二乗誤差が変化します。**

# %%
pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

print('訓練データに対する平均二乗誤差＝{:0.2f}'.format(np.mean((np.array(Y_train, dtype = int) - pred_train) ** 2)))
print('テストデータに対する平均二乗誤差＝{:0.2f}'.format(np.mean((np.array(Y_test, dtype = int) - pred_test) ** 2)))
# Out:
# 訓練データに対する平均二乗誤差＝0.28
# テストデータに対する平均二乗誤差＝1.04

# %% [markdown]
# ### 残差プロット
# また、残差プロット（横軸に予測値、縦軸に実際の値との差をプロットしたもの）をプロットします。
# 残差プロットは、y=0の水平線に近いほど、良い精度のデータといえます

# %%
# 学習用データの残差プロット
train = plt.scatter(pred_train,(pred_train-Y_train),c='b',alpha=0.5)

# テスト用データの残差プロット
test = plt.scatter(pred_test,(pred_test-Y_test),c='r',alpha=0.5)

# y=0の水平線
plt.hlines(y=0,xmin=-8,xmax=8)

plt.legend((train,test),('Training','Test'),loc='lower left')
plt.title('Residual Plots')
# Out:
# Text(0.5, 1.0, 'Residual Plots')

# %% [markdown]
# ### P値を求める
# sklearn.linear_model.LinearRegressionでは各説明変数のp値が求められないので、statsmodelsを使って重回帰分析をします。標準化したデータを用い、7:3に分割した訓練データを用います。

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df = pd.read_csv("senkei.csv", index_col=0)  # ← データファイルのパスを正しく指定して下さい。

# データフレームの各列を標準化
df2 = df.apply(lambda x: (x - np.mean(x)) / np.std(x))

# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# print(type(X))
# print(type(Y))

# 学習用データとテスト用データを7:3に分割する；ランダム性あり
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# print(type(X_train))
# print(type(Y_train))

# データをロード
X_train_c = sm.add_constant(X_train)  # 定数項（切片）を追加

# print(type(X_train_c))

# OLSモデルの構築とフィット
ols_model = sm.OLS(Y_train, X_train_c)
results = ols_model.fit()

# 結果の要約を出力
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.562
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     7.952
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           6.48e-05
# Time:                        12:03:15   Log-Likelihood:                -30.482
# No. Observations:                  37   AIC:                             72.96
# Df Residuals:                      31   BIC:                             82.63
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1207      0.182      0.663      0.512      -0.250       0.492
# x2             0.1798      0.175      1.026      0.313      -0.178       0.537
# x3             0.4071      0.118      3.445      0.002       0.166       0.648
# x4             0.2302      0.742      0.310      0.759      -1.284       1.744
# x5            -0.0184      0.168     -0.110      0.913      -0.360       0.324
# x6             0.1482      0.109      1.363      0.183      -0.074       0.370
# ==============================================================================
# Omnibus:                        2.003   Durbin-Watson:                   1.515
# Prob(Omnibus):                  0.367   Jarque-Bera (JB):                1.394
# Skew:                           0.475   Prob(JB):                        0.498
# Kurtosis:                       3.044   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(results.params)
# Out:
# [0.12884744 0.2228974  0.40873472 0.09238801 0.13193111 0.06321065]

# %%
print(df2.columns)
# Out:
# Index(['sales', 'insta_post', 'insta_good', 'flyer', 'event', 'new_item',
#        'holiday'],
#       dtype='object')

# %%
# 主要な結果の出力
print(f"自由度調整済み決定係数: {results.rsquared_adj:.4f}")
print("- 説明変数: 標準化偏回帰係数, P値")
for i, (coef, p_value) in enumerate(zip(results.params[1:], results.pvalues[1:])):
    print(f"- {df2.columns[i + 1]}: {coef:.4f}, {p_value:.4f}")
# Out:
# 自由度調整済み決定係数: 0.4913
# - 説明変数: 標準化偏回帰係数, P値
# - insta_post: 0.1798, 0.3128
# - insta_good: 0.4071, 0.0017
# - flyer: 0.2302, 0.7586
# - event: -0.0184, 0.9133
# - new_item: 0.1482, 0.1828

# %% [markdown]
# ### 主な結果の見方
# *  **R-squared（決定係数）**は目的変数の変動の何％を説明変数全体が説明できているかを示す。大きい方がよい。
# *  **Adj. R-squared（自由度調整済み決定係数）**
# *  **Prob (F-statistic)（有意F）**は「重回帰式のすべての偏回帰係数が0」の検定のP値であり、重回帰式全体の有意性を示す。値が小さいほうが重回帰式の当てはまりがよいことを示す。
# *  **coef（偏回帰係数の値）**偏回帰係数は、”その説明変数の値が1増えた時に目的変数がどれくらい増える(または減る)か”を表しています。
# つまり偏回帰係数が5である変数の場合、その変数が1増えれば目的変数が5増えるという意味になります。\
# また他の変数と比較してどの説明変数が目的変数に影響を与えているのか知りたい場合は、データを事前に標準化してから回帰分析を実行します。データを標準化することで変数間の尺度がそろうため、説明変数同士の比較が可能となります。標準化されたデータの偏回帰係数のことを**標準化偏回帰係数**と呼び、通常の偏回帰係数と区別します。**標準化偏回帰係数の絶対値**が大きければ大きいほど目的変数への影響が強いと解釈します。例えば、変数Aと変数Bの標準化偏回帰係数がそれぞれ0.5と-0.6であった場合、”変数Bの方が目的変数に強く影響しており、変数Bが増えれば増えるほど目的変数は減少する”と解釈します。\
# まとめると、偏回帰係数はその説明変数が目的変数にどれくらい影響するか、標準化偏回帰係数はその説明変数が他の変数と比べてどれくらい目的変数に影響するかを意味します。偏回帰係数と標準化偏回帰係数は解釈の仕方が変わってくるため、結果を見る時は注意しましょう。
# *  **P(>|t|)（P値）**は、ある説明変数が目的変数に影響しているかどうかを示す。各偏回帰係数の統計的有意性を示す検定（帰無仮説：偏回帰係数βⱼ=0）のP値である。ここでのP値は、偏回帰係数が本当は0なのに、サンプルから計算した偏回帰係数が計算結果以上に0から隔たってしまう確率のこと。この確率が小さい場合、すなわち、偶然そういう結果が出ることは極めてまれであると言える場合は、前提とした仮説が誤っていたと言える。つまり、P値が有意水準（たとえば0.05）を下回っている変数は目的変数に影響している（偏回帰係数は0ではない）と言える。P値が有意水準以上の変数は「目的変数に影響しているとは言い切れない」と解釈。P値が有意水準以上の変数を説明変数から除くというのはモデル選択法の1つ。
# *  **[0.025      0.975]（95%信頼区間）**

# %% [markdown]
# **P値**についての解説は、たとえば、[ここ](https://www.nri.com/jp/knowledge/glossary/lst/alphabet/p_value)を参照

# %% [markdown]
# ## 演習問題

# %% [markdown]
# ### 問題１
# A) 53個のデータ全てを用い、標準化された全ての説明変数を用いて重回帰分析した場合の、自由度調整済み決定係数と標準化偏回帰係数と各説明変数のP値を求めなさい。\
# B) 5%有意水準以上のP値となった説明変数を挙げなさい。\
# C) B)の説明変数を除き、53個のデータ全てを用い、重回帰分析した場合の、自由度調整済み決定係数と標準化偏回帰係数と各説明変数のP値を求めなさい。

# %%
# A)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

df = pd.read_csv("senkei.csv", index_col=0)  # ← データファイルのパスを正しく指定して下さい。

# データフレームの各列を標準化
df2 = df.apply(lambda x: (x - np.mean(x)) / np.std(x))

# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# データをロード
X_c = sm.add_constant(X)  # 定数項（切片）を追加

# OLSモデルの構築とフィット
ols_model = sm.OLS(Y, X_c)
results = ols_model.fit()

# 結果の要約を出力
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.742
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     22.08
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           4.87e-12
# Time:                        12:03:35   Log-Likelihood:                -39.274
# No. Observations:                  53   AIC:                             92.55
# Df Residuals:                      46   BIC:                             106.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.004e-17      0.075   4.01e-16      1.000      -0.151       0.151
# x1             0.1449      0.116      1.246      0.219      -0.089       0.379
# x2             0.2404      0.147      1.640      0.108      -0.055       0.535
# x3             0.4240      0.104      4.093      0.000       0.216       0.633
# x4             0.3388      0.107      3.153      0.003       0.122       0.555
# x5            -0.0752      0.132     -0.572      0.570      -0.340       0.190
# x6             0.1237      0.088      1.407      0.166      -0.053       0.301
# ==============================================================================
# Omnibus:                        2.447   Durbin-Watson:                   1.159
# Prob(Omnibus):                  0.294   Jarque-Bera (JB):                1.639
# Skew:                           0.402   Prob(JB):                        0.441
# Kurtosis:                       3.310   Cond. No.                         4.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(results.params)
# Out:
# [ 3.00379692e-17  1.44936812e-01  2.40394028e-01  4.24019655e-01
#   3.38814639e-01 -7.52202549e-02  1.23663296e-01]

# %%
print(df2.columns)
# Out:
# Index(['sales', 'insta_post', 'insta_good', 'flyer', 'event', 'new_item',
#        'holiday'],
#       dtype='object')

# %%
# 主要な結果の出力
print(f"自由度調整済み決定係数: {results.rsquared_adj:.4f}")
print("- 説明変数: 標準化偏回帰係数, P値")
for i, (coef, p_value) in enumerate(zip(results.params[1:], results.pvalues[1:])):
    print(f"- {df2.columns[i + 1]}: {coef:.4f}, {p_value:.4f}")
# Out:
# 自由度調整済み決定係数: 0.7086
# - 説明変数: 標準化偏回帰係数, P値
# - insta_post: 0.1449, 0.2192
# - insta_good: 0.2404, 0.1078
# - flyer: 0.4240, 0.0002
# - event: 0.3388, 0.0028
# - new_item: -0.0752, 0.5704
# - holiday: 0.1237, 0.1662

# %% [markdown]
# sklearn.linear_model.LinearRegressionでの結果と同じかの確認用
#
#          Name  Coefficients
# 0  insta_post      0.144937
# 1  insta_good      0.240394
# 2       flyer      0.424020
# 3       event      0.338815
# 4    new_item     -0.075220
# 5     holiday      0.123663
# 1.713800285331052e-17

# %%
# 解答例から：dfをolsモデルの入力にした方が結果が見やすい
# データをロード
X_c = sm.add_constant(df2.iloc[:, 1:7])  # 定数項（切片）を追加

# OLSモデルの構築とフィット
ols_model = sm.OLS(df2.iloc[:, 0], X_c)
results = ols_model.fit()

# 結果の要約を出力
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.742
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     22.08
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           4.87e-12
# Time:                        12:03:48   Log-Likelihood:                -39.274
# No. Observations:                  53   AIC:                             92.55
# Df Residuals:                      46   BIC:                             106.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.004e-17      0.075   4.01e-16      1.000      -0.151       0.151
# insta_post     0.1449      0.116      1.246      0.219      -0.089       0.379
# insta_good     0.2404      0.147      1.640      0.108      -0.055       0.535
# flyer          0.4240      0.104      4.093      0.000       0.216       0.633
# event          0.3388      0.107      3.153      0.003       0.122       0.555
# new_item      -0.0752      0.132     -0.572      0.570      -0.340       0.190
# holiday        0.1237      0.088      1.407      0.166      -0.053       0.301
# ==============================================================================
# Omnibus:                        2.447   Durbin-Watson:                   1.159
# Prob(Omnibus):                  0.294   Jarque-Bera (JB):                1.639
# Skew:                           0.402   Prob(JB):                        0.441
# Kurtosis:                       3.310   Cond. No.                         4.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# B) 5%有意水準以上のP値となった説明変数：
# *   x1: insta_post
# *   x2: insta_good
# *   x5: new_item
# *   x6: holiday

# %%
# C)
# 説明変数 x1: insta_post, x2: insta_good, x5: new_item, x6: holidayを一気に削除
X = df2.iloc[:, [3, 4]].values

# 目的変数
Y = df2.iloc[:, 0].values

# データをロード
X_c = sm.add_constant(X)  # 定数項（切片）を追加

# OLSモデルの構築とフィット
ols_model = sm.OLS(Y, X_c)
results = ols_model.fit()

# 結果の要約を出力
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     53.30
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           4.02e-13
# Time:                        12:03:58   Log-Likelihood:                -44.949
# No. Observations:                  53   AIC:                             95.90
# Df Residuals:                      50   BIC:                             101.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.282e-18      0.080   2.86e-17      1.000      -0.161       0.161
# x1             0.5838      0.083      7.032      0.000       0.417       0.751
# x2             0.4459      0.083      5.371      0.000       0.279       0.613
# ==============================================================================
# Omnibus:                        6.930   Durbin-Watson:                   1.217
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                5.960
# Skew:                           0.689   Prob(JB):                       0.0508
# Kurtosis:                       3.895   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 主要な結果の出力
print(f"自由度調整済み決定係数: {results.rsquared_adj:.4f}")
print("- 説明変数: 標準化偏回帰係数, P値")
for i, (coef, p_value) in enumerate(zip(results.params[1:], results.pvalues[1:])):
    print(f"- {df2.iloc[:, [3, 4]].columns[i]}: {coef:.4f}, {p_value:.4f}")
# Out:
# 自由度調整済み決定係数: 0.6679
# - 説明変数: 標準化偏回帰係数, P値
# - flyer: 0.5838, 0.0000
# - event: 0.4459, 0.0000

# %%
# 解答例から：5%有意水準以上のP値となった説明変数をプログラムで削除
# C)

# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# データをロード
X_c = sm.add_constant(X)  # 定数項（切片）を追加

# OLSモデルの構築とフィット
ols_model = sm.OLS(Y, X_c)
results = ols_model.fit()

# 5%有意水準以上のP値となった説明変数のインデックスを取得
insignificant_vars_indices = np.where(results.pvalues[1:] > 0.05)[0]

# 5%有意水準以上のP値となった説明変数を削除
X_new = np.delete(X, insignificant_vars_indices, axis=1)

# 定数項（切片）を追加
X_new_c = sm.add_constant(X_new)

# 新しい説明変数を使用してOLSモデルを構築とフィット
new_ols_model = sm.OLS(Y, X_new_c)
new_results = new_ols_model.fit()

# 新しいモデルの結果を出力
print(new_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     53.30
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           4.02e-13
# Time:                        12:04:09   Log-Likelihood:                -44.949
# No. Observations:                  53   AIC:                             95.90
# Df Residuals:                      50   BIC:                             101.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.282e-18      0.080   2.86e-17      1.000      -0.161       0.161
# x1             0.5838      0.083      7.032      0.000       0.417       0.751
# x2             0.4459      0.083      5.371      0.000       0.279       0.613
# ==============================================================================
# Omnibus:                        6.930   Durbin-Watson:                   1.217
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                5.960
# Skew:                           0.689   Prob(JB):                       0.0508
# Kurtosis:                       3.895   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 別の解答例
# C)
# 5%有意水準以外のp値を持つ説明変数のインデックスを取得
significant_vars = pd.Series(results.pvalues).loc[results.pvalues <= 0.05].index

# 有意な説明変数のみを含む新しいデータ行列を作成
X_significant = X[:, np.isin(np.arange(X.shape[1]), significant_vars)]

# 定数項を追加
X_significant = sm.add_constant(X_significant)

# 新しいデータ行列でモデルを再構築
ols_model = sm.OLS(Y, X_significant)
results = ols_model.fit()

# 自由度調整済み決定係数
adjusted_r_squared = results.rsquared_adj

# 標準化偏回帰係数
standardized_coef = results.params / results.bse

# 各説明変数のp値
p_values = results.pvalues

# 結果の出力
print("自由度調整済み決定係数:", adjusted_r_squared)
print("標準化偏回帰係数:", standardized_coef)
print("各説明変数のp値:", p_values)
# Out:
# 自由度調整済み決定係数: 0.43863512552978223
# 標準化偏回帰係数: [2.19669411e-17 5.89340644e+00 2.97132330e+00]
# 各説明変数のp値: [1.0000000e+00 3.2037688e-07 4.5488542e-03]

# %% [markdown]
# 実は、説明変数選択法としては、P値が有意水準以上の説明変数を一気にすべて削除するという変数選択は不適切だと言われていて、**P値が最大のものから、説明変数を「１つずつ」減らしていく方法（変数減少法）**が推奨されている。以下では、これをやって、一気にすべて削除してしまう方法と結果を比べてみよう。
#
# なお、**予測が目的**（今回のデータでいうと、売り上げの予測をできるだけ正確にしたい）の場合は、**変数選択は不要**で、使える変数はなるべく使った方がよい（データがあるのに使わないのはもったいない）と言われていて、不必要な変数があってもあまり害はないことが知られている。
#
# これに対して、**変数選択が必要**なのは、次の場合：
# *  分析の初期段階で、候補となる変数群から必要な変数を選択したい。
# *  予備調査の結果から本調査を行うが、本調査で多くの項目を調査するのはコストがかかるので絞り込みたい。
# *  制御すべき変数を同定したい（たくさんの変数を制御するのは難しい）。
#
# [以上の情報の出典：成蹊大学・横浜市立大学 岩崎学先生の講義資料から]

# %%
# 説明変数 まず、5: new_itemを削除
X = df2.iloc[:, [1, 2, 3, 4, 6]].values

# 目的変数
Y = df2.iloc[:, 0].values

# データをロード
X_c = sm.add_constant(X)  # 定数項（切片）を追加

# OLSモデルの構築とフィット
ols_model = sm.OLS(Y, X_c)
results = ols_model.fit()

# 結果の要約を出力
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     26.81
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           1.04e-12
# Time:                        12:04:21   Log-Likelihood:                -39.462
# No. Observations:                  53   AIC:                             90.92
# Df Residuals:                      47   BIC:                             102.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.004e-17      0.074   4.04e-16      1.000      -0.150       0.150
# x1             0.1077      0.096      1.125      0.266      -0.085       0.300
# x2             0.1959      0.123      1.589      0.119      -0.052       0.444
# x3             0.4259      0.103      4.143      0.000       0.219       0.633
# x4             0.3757      0.085      4.405      0.000       0.204       0.547
# x5             0.1384      0.083      1.658      0.104      -0.029       0.306
# ==============================================================================
# Omnibus:                        2.053   Durbin-Watson:                   1.165
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.217
# Skew:                           0.301   Prob(JB):                        0.544
# Kurtosis:                       3.436   Cond. No.                         3.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 主要な結果の出力
print(f"自由度調整済み決定係数: {results.rsquared_adj:.4f}")
print("- 説明変数: 標準化偏回帰係数, P値")
for i, (coef, p_value) in enumerate(zip(results.params[1:], results.pvalues[1:])):
    print(f"- {df2.iloc[:, [1, 2, 3, 4, 6]].columns[i]}: {coef:.4f}, {p_value:.4f}")
# Out:
# 自由度調整済み決定係数: 0.7128
# - 説明変数: 標準化偏回帰係数, P値
# - insta_post: 0.1077, 0.2662
# - insta_good: 0.1959, 0.1189
# - flyer: 0.4259, 0.0001
# - event: 0.3757, 0.0001
# - holiday: 0.1384, 0.1039

# %%
# 説明変数 つづいて、1: insta_postを削除
X = df2.iloc[:, [2, 3, 4, 6]].values

# 目的変数
Y = df2.iloc[:, 0].values

# データをロード
X_c = sm.add_constant(X)  # 定数項（切片）を追加

# OLSモデルの構築とフィット
ols_model = sm.OLS(Y, X_c)
results = ols_model.fit()

# 結果の要約を出力
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.711
# Method:                 Least Squares   F-statistic:                     33.02
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           3.08e-13
# Time:                        12:04:29   Log-Likelihood:                -40.166
# No. Observations:                  53   AIC:                             90.33
# Df Residuals:                      48   BIC:                             100.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.004e-17      0.075   4.03e-16      1.000      -0.150       0.150
# x1             0.2550      0.112      2.278      0.027       0.030       0.480
# x2             0.4155      0.103      4.047      0.000       0.209       0.622
# x3             0.3979      0.083      4.782      0.000       0.231       0.565
# x4             0.1055      0.078      1.346      0.185      -0.052       0.263
# ==============================================================================
# Omnibus:                        1.493   Durbin-Watson:                   1.181
# Prob(Omnibus):                  0.474   Jarque-Bera (JB):                1.071
# Skew:                           0.348   Prob(JB):                        0.586
# Kurtosis:                       3.040   Cond. No.                         2.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 主要な結果の出力
print(f"自由度調整済み決定係数: {results.rsquared_adj:.4f}")
print("- 説明変数: 標準化偏回帰係数, P値")
for i, (coef, p_value) in enumerate(zip(results.params[1:], results.pvalues[1:])):
    print(f"- {df2.iloc[:, [2, 3, 4, 6]].columns[i]}: {coef:.4f}, {p_value:.4f}")
# Out:
# 自由度調整済み決定係数: 0.7112
# - 説明変数: 標準化偏回帰係数, P値
# - insta_good: 0.2550, 0.0272
# - flyer: 0.4155, 0.0002
# - event: 0.3979, 0.0000
# - holiday: 0.1055, 0.1845

# %%
# 説明変数 つづいて、6: holidayを削除
X = df2.iloc[:, [2, 3, 4]].values

# 目的変数
Y = df2.iloc[:, 0].values

# データをロード
X_c = sm.add_constant(X)  # 定数項（切片）を追加

# OLSモデルの構築とフィット
ols_model = sm.OLS(Y, X_c)
results = ols_model.fit()

# 結果の要約を出力
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     42.71
# Date:                Tue, 24 Jun 2025   Prob (F-statistic):           1.03e-13
# Time:                        12:04:34   Log-Likelihood:                -41.149
# No. Observations:                  53   AIC:                             90.30
# Df Residuals:                      49   BIC:                             98.18
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.004e-17      0.075      4e-16      1.000      -0.151       0.151
# x1             0.2976      0.108      2.749      0.008       0.080       0.515
# x2             0.3998      0.103      3.887      0.000       0.193       0.606
# x3             0.3753      0.082      4.567      0.000       0.210       0.540
# ==============================================================================
# Omnibus:                        0.344   Durbin-Watson:                   1.110
# Prob(Omnibus):                  0.842   Jarque-Bera (JB):                0.161
# Skew:                           0.135   Prob(JB):                        0.923
# Kurtosis:                       2.984   Cond. No.                         2.53
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# 主要な結果の出力
print(f"自由度調整済み決定係数: {results.rsquared_adj:.4f}")
print("- 説明変数: 標準化偏回帰係数, P値")
for i, (coef, p_value) in enumerate(zip(results.params[1:], results.pvalues[1:])):
    print(f"- {df2.iloc[:, [2, 3, 4]].columns[i]}: {coef:.4f}, {p_value:.4f}")
# Out:
# 自由度調整済み決定係数: 0.7064
# - 説明変数: 標準化偏回帰係数, P値
# - insta_good: 0.2976, 0.0083
# - flyer: 0.3998, 0.0003
# - event: 0.3753, 0.0000

# %% [markdown]
# **１つずつ**減らしていく方法（**変数減少法**）にすると、2: insta_good も説明変数として残った。その分、自由度調整済み決定係数の値も大きくなった。0.6679→0.7064

# %% [markdown]
# ### 問題２
# 学習用データとテスト用データを1:1で分割し、学習用データだけを用いて、問題１のA), B), C)を再実行しなさい。なお、C)は、**１つずつ**変数を減らす方法を使うこと。

# %%
# A)

# %% [markdown]
# B)

# %%
# C)

# %% [markdown]
# ### 問題３
# 学習用データをもっと減らした場合にどうなるかを実験し、学習データ数が、自由度調整済み決定係数や標準化偏回帰係数や各説明変数のP値に与える影響について考察しなさい。
# * 学習用データ数をどれくらいに減らして実験すると、考察に役立つでしょうか？また、何通りくらいの数で実験するとよいでしょうか？これらのことも考えながら実験を設計しましょう。
# * 学習用データ数をより減らすと、（ランダムに選んで減らす訳ですが、）そこでたまたま選ばれたデータがどのようなものであったかの影響をより強く受けるようになると想像されます。この点も考慮して実験するとよいでしょう。どのように実験を計画すると、（たまたまの選択に影響された結果でなく）信頼できる結果が得られるでしょうか？
# * 実験結果はグラフで表示すると分かりやすいです。どのようなグラフを書くとよいかも考えましょう。AI (Geminiという名前に変わりましたね)に相談するとグラフの書き方、そのためのプログラムの書き方も教えてもらえると思います。

# %% [markdown]
# ### 問題3への解答方針
# *  **自由度調整済み決定係数**への影響と標準化偏回帰係数に与える影響は似ていると思うので、以下では、標準化偏回帰係数の実験は省略します。標準化偏回帰係数を調べる場合は、どの説明変数について調べるか、すべての説明変数について調べるのか、個々の説明変数への影響の平均的傾向を調べるのか、といったことを考える必要があります。
# *  各説明変数のP値への影響を調べるという問題を出したのですが、ここでは、これと同様の変化をすると思われる、**Prob (F-statistic)（有意F）**への影響を調べることにします。各説明変数のP値への影響を調べる場合は、どの説明変数について調べるか、すべての説明変数について調べるのか、個々の説明変数への影響の平均的傾向を調べるのか、といったことを考える必要があります。

# %% [markdown]
# ### 問題3のプログラム解説
# 以下のプログラムは、次のプロンプトでAIに作ってもらったけれどエラーが出るなどいろいろあったので、手で修正を加えた結果です。
#
# プログラムの最初の10行（目的変数を作るところまで）は、このノートブックで既に作成済みのプログラムをコピーしてきたものです。このようにこれまでのプログラムが使えるところは、AIに頼むのでなく、動くプログラムを持ってくることが、成功への早道です。
#
# **prompt:** 元のデータセットのデータの10%, 20%, 30%, ..., 90%, 100%のデータを使って学習した場合の、自由度調整済み決定係数と、有意Fの変化の様子を調べるプログラムをstatsmodelsを使って書いて下さい。
#
# この課題は、いろいろなサイズのデータで学習して評価する、という課題なので、「指定したサイズのデータで学習、評価する」ことが繰り返し、出てきます。このようなケースでは、この**繰り返し出てくる部分を関数にする**、というのが鉄則です。evaluate_modelという関数が定義されています。
#
# このように、複雑な問題を扱うためには、関数に分かるのがお勧めで、関数を含むプログラムを作る場合は、AIへの依頼は、
# 1. **まず、どのような関数を作ればよいかを尋ねる**
# 2. **次に、それぞれの関数の作成を依頼する**
#
# という手順がお勧めです。

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

df = pd.read_csv("senkei.csv", index_col=0)  # ← データファイルのパスを正しく指定して下さい。

# データフレームの各列を標準化
df2 = df.apply(lambda x: (x - np.mean(x)) / np.std(x))

# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# 関数の定義：adjusted R^2 と F-statistic を 指定したデータサイズに対して算出する
def evaluate_model(data_size):
    # 学習セットとテストセットに、指定したサイズでランダム分割する（学習セットだけ使用）
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=data_size)

    # Add a constant term to the independent variables
    X_train_c = sm.add_constant(X_train)

    # OLSモデルの構築とフィット
    ols_model = sm.OLS(Y_train, X_train_c)
    results = ols_model.fit()

    # 結果を返す
    return results.rsquared_adj, results.f_pvalue

# 結果を格納するリストの初期化：空リストにする
r2_adjusted_list = []
f_statistic_list = []

# いろいろなデータサイズでループ：100%は分割にならないので、90%まで実施。
for data_size in range(10, 100, 10):
    # adjusted R^2 と F-statisticを算出
    r2_adjusted, f_statistic = evaluate_model(data_size / 100)

    # 結果をリストに追加
    r2_adjusted_list.append(r2_adjusted)
    f_statistic_list.append(f_statistic)

# 結果をプリント
print("Data Size\tAdjusted R^2\tProb (F-statistic)")
for i in range(len(r2_adjusted_list)):
    print(f"{i+1}0%\t\t{r2_adjusted_list[i]:.4f}\t\t{f_statistic_list[i]:.8f}")
# Out:
# Data Size	Adjusted R^2	Prob (F-statistic)
# 10%		0.9996		0.01252979
# 20%		0.9439		0.00011253
# 30%		0.6383		0.00243046
# 40%		0.8734		0.00000037
# 50%		0.3549		0.01473688
# 60%		0.7362		0.00000016
# 70%		0.6028		0.00000173
# 80%		0.7303		0.00000000
# 90%		0.7076		0.00000000

# %% [markdown]
# *  ↑これは、一回の試行の結果。特に、**データサイズが小さいところでは、ランダム選択の影響で変動が大**きく、**1回だけの試行の結果は信頼がおけない**と思われる。
# *  そこで、下のプログラムは、**試行を10回して、平均**を取って、とAIに依頼して作ったもの

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import numpy as np

df = pd.read_csv("senkei.csv", index_col=0)  # ← データファイルのパスを正しく指定して下さい。

# データフレームの各列を標準化
df2 = df.apply(lambda x: (x - np.mean(x)) / np.std(x))

# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# Define a function to calculate the adjusted R^2 and F-statistic for different data sizes
def evaluate_model(data_size):
    # Initialize lists to store results for each trial
    r2_adjusted_trial = []
    f_statistic_trial = []

    # 10試行のループ
    for _ in range(10):
        # Split data into train and test sets
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=data_size)

        # Add a constant term to the independent variables
        X_train_c = sm.add_constant(X_train)

        # OLSモデルの構築とフィット
        ols_model = sm.OLS(Y_train, X_train_c)
        results = ols_model.fit()

        # Append the results of this trial
        r2_adjusted_trial.append(results.rsquared_adj)
        f_statistic_trial.append(results.f_pvalue)

    # 10試行の平均を算出
    r2_adjusted = np.mean(r2_adjusted_trial)
    f_statistic = np.mean(f_statistic_trial)

    # Return the average results
    return r2_adjusted, f_statistic

# Initialize empty lists to store the results
r2_adjusted_list = []
f_statistic_list = []

# Loop through different data sizes
for data_size in range(10, 100, 10):
    # Calculate the adjusted R^2 and F-statistic, averaging over 10 trials
    r2_adjusted, f_statistic = evaluate_model(data_size / 100)

    # Append the results to the lists
    r2_adjusted_list.append(r2_adjusted)
    f_statistic_list.append(f_statistic)

# Print the results
print("Data Size\tAdjusted R^2\tProb (F-statistic)")
for i in range(len(r2_adjusted_list)):
    print(f"{i+1}0%\t\t{r2_adjusted_list[i]:.4f}\t\t{f_statistic_list[i]:.8f}")
# Out:
# Data Size	Adjusted R^2	Prob (F-statistic)
# 10%		nan		nan
# 20%		0.6651		0.06847149
# 30%		0.6447		0.01016170
# 40%		0.7356		0.00046667
# 50%		0.7206		0.00004668
# 60%		0.6391		0.00019974
# 70%		0.6845		0.00000513
# 80%		0.7171		0.00000156
# 90%		0.7406		0.00000000
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)

# %% [markdown]
# *  ↑10％のサイズでは、エラーが出て算出できなかったという結果。これはデータサイズが小さくなり過ぎた結果だと思われるため、やむを得ないだろう。上記の1回だけ試行のときには、エラーが出なかった訳だが、10回試行すると、そのうちのどれかでエラーが出る可能性が高まるということだろう。１０％は、データ5個しかないからね。
# *  下のプログラムは、**各試行のばらつき具合も表示**すれば、さらに的確に状況が把握できると考えて、平均に加えて**標準偏差**も算出することにした。この追加をAIに依頼。
# *  さらに、結果をグラフ化するように、AIに依頼。**グラフ化（可視化）は、データ分析においてとても大切**。
# *  **グラフを見ると、10回の平均では、安定してないことが分かった**ので、**100回の平均に変更**。**皆さんも、100回を10回に変更してプログラムを動かしてみて、それを実感して下さい**。

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("senkei.csv", index_col=0)  # ← データファイルのパスを正しく指定して下さい。

# データフレームの各列を標準化
df2 = df.apply(lambda x: (x - np.mean(x)) / np.std(x))

# 説明変数
X = df2.iloc[:, 1:7].values

# 目的変数
Y = df2.iloc[:, 0].values

# Define a function to calculate the adjusted R^2 and F-statistic for different data sizes
def evaluate_model(data_size):
    # Initialize lists to store results for each trial
    r2_adjusted_trial = []
    f_statistic_trial = []

    # 100試行のループ
    for _ in range(100):
        # Split data into train and test sets
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=data_size)

        # Add a constant term to the independent variables
        X_train_c = sm.add_constant(X_train)

        # OLSモデルの構築とフィット
        ols_model = sm.OLS(Y_train, X_train_c)
        results = ols_model.fit()

        # Append the results of this trial
        r2_adjusted_trial.append(results.rsquared_adj)
        f_statistic_trial.append(results.f_pvalue)

    # Calculate the average and standard deviation of the 10 trials
    r2_adjusted = np.mean(r2_adjusted_trial)
    r2_adjusted_std = np.std(r2_adjusted_trial)
    f_statistic = np.mean(f_statistic_trial)
    f_statistic_std = np.std(f_statistic_trial)

    # Return the average results and standard deviations
    return r2_adjusted, r2_adjusted_std, f_statistic, f_statistic_std

# Initialize empty lists to store the results
r2_adjusted_list = []
r2_adjusted_std_list = []
f_statistic_list = []
f_statistic_std_list = []

# Loop through different data sizes
for data_size in range(10, 100, 10):
    # Calculate the adjusted R^2 and F-statistic, averaging over 10 trials
    r2_adjusted, r2_adjusted_std, f_statistic, f_statistic_std = evaluate_model(data_size / 100)

    # Append the results to the lists
    r2_adjusted_list.append(r2_adjusted)
    r2_adjusted_std_list.append(r2_adjusted_std)
    f_statistic_list.append(f_statistic)
    f_statistic_std_list.append(f_statistic_std)

# Print the results
print("Data Size\tAdjusted R^2\tStd (R^2)\tProb (F-statistic)\tStd (F-statistic)")
for i in range(len(r2_adjusted_list)):
    print(f"{i+1}0%\t\t{r2_adjusted_list[i]:.4f}\t\t{r2_adjusted_std_list[i]:.4f}\t\t{f_statistic_list[i]:.8f}\t\t{f_statistic_std_list[i]:.8f}")

# グラフで可視化
plt.figure(figsize=(8, 6))
plt.subplot(2, 1, 1)
plt.plot(range(10, 100, 10), r2_adjusted_list, label="Average Adjusted R²")
plt.fill_between(range(10, 100, 10), np.array(r2_adjusted_list) - np.array(r2_adjusted_std_list), np.array(r2_adjusted_list) + np.array(r2_adjusted_std_list), alpha=0.3)
plt.xlabel("Data Size (%)")
plt.ylabel("Adjusted R²")
plt.title("Adjusted R² vs. Data Size")
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(range(10, 100, 10), f_statistic_list, label="Average Prob (F-statistic)")
plt.fill_between(range(10, 100, 10), np.array(f_statistic_list) - np.array(f_statistic_std_list), np.array(f_statistic_list) + np.array(f_statistic_std_list), alpha=0.3)
plt.xlabel("Data Size (%)")
plt.ylabel("Prob (F-statistic)")
plt.title("Prob (F-statistic) vs. Data Size")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# Data Size	Adjusted R^2	Std (R^2)	Prob (F-statistic)	Std (F-statistic)
# 10%		nan		nan		nan		nan
# 20%		0.6690		0.2694		0.06875480		0.12967474
# 30%		0.7098		0.2002		0.01600577		0.04196570
# 40%		0.6851		0.1718		0.00312146		0.00740160
# 50%		0.7202		0.1306		0.00029360		0.00090101
# 60%		0.7133		0.1110		0.00004435		0.00015299
# 70%		0.6996		0.1106		0.00000862		0.00002591
# 80%		0.7172		0.0853		0.00000059		0.00000236
# 90%		0.7126		0.0577		0.00000004		0.00000018

# %% [markdown]
# ### 問題4
# 1. 上のグラフ（試行数100）を見て分かったことを書きなさい。
# 2. 試行数を10に減らしたり、1000に増やしたりして、分かったことを書きなさい。試行数10の場合は、1回だけでなく、何回か試してみなさい。試行数を5に減らすと、エラーが起こらず10％の結果も表示されることがありますね。
# 3. 下のグラフは縦軸を対数軸にすると、データサイズが比較的大きいところでの変化も視覚化できるはずです。試して下さい。AIに頼むとできるはず。対数軸にした場合と、対数軸でなく元の軸のままの場合を見比べて、分かったことを書きなさい。

# %% [markdown]
# ### 問題4の解答をここに記入

# %% [markdown]
# １．で分かったこと：
#
# Geminiとのチャットの一例を掲載します：
#
# 問題３の最後に掲載されたグラフを見て分かったことを書いて下さい。
#
# 問題 3 の最後に掲載されたグラフから分かることは以下の通りです。
#
# Adjusted R² (自由度調整済み決定係数) について:
#
# - データサイズが小さい（特に 20%や 30%）場合、Adjusted R² の値が大きく変動しており、標準偏差も大きいことがわかります。これは、データサイズが小さいとランダムなデータの分割による影響を強く受けるため、結果が不安定になることを示唆しています。
# - データサイズが大きくなるにつれて、Adjusted R² の値は比較的安定し、標準偏差も小さくなっています。データサイズが十分にある場合、モデルの当てはまりの評価がより信頼できるものになります。
# - 全体的に、データサイズが大きくなるにつれて Adjusted R² の平均値はわずかに増加傾向にあるか、あるいはある程度以上のデータサイズではほぼ横ばいになるように見えます。
#
# Prob (F-statistic) (有意 F) について:
#
# - データサイズが小さい場合、Prob (F-statistic) の値も大きく変動しており、標準偏差も大きいです。これは、重回帰式全体の有意性の検定結果がデータサイズによって不安定になることを示しています。
# - データサイズが大きくなるにつれて、Prob (F-statistic) の値は非常に小さくなり、標準偏差も急激に小さくなっています。これは、データサイズが大きくなるほど、重回帰式全体が統計的に有意である（偏回帰係数の少なくとも一つは 0 ではない）と判断できる信頼性が高まることを示しています。
# - データサイズが大きくなるにつれて、Prob (F-statistic) の平均値は 0 に近づいていきます。
#
#
# これらの観察から、データサイズが小さい場合、線形回帰モデルの評価指標（Adjusted R² や Prob (F-statistic)）はデータの分割方法によって大きく変動しやすく、信頼性が低いことがわかります。より信頼性の高いモデル評価を行うためには、ある程度のデータサイズが必要であると言えます。

# %% [markdown]
# ２．で分かったこと：
#
# （実際に試行数を変えて実験して下さい。実験結果のグラフを観察して分かったことを書いて下さい。試行数の変え方が分からない人は、Geminiに尋ねて下さい。）

# %% [markdown]
# ３．のプログラム↓

# %%
# prompt: 問題3の有意Fのグラフの縦軸を対数軸にしたものと、元のままの縦軸の有意Fのグラフを見比べられるように縦に並べて出力する。自由度調整済み決定係数のグラフは不要です。

# グラフで可視化 (縦軸を対数軸にしたものと、元のままの縦軸の有意Fのグラフ)
plt.figure(figsize=(8, 6))

# 元の縦軸の有意Fのグラフ
plt.subplot(2, 1, 1)
plt.plot(range(10, 100, 10), f_statistic_list, label="Average Prob (F-statistic)")
plt.fill_between(range(10, 100, 10), np.array(f_statistic_list) - np.array(f_statistic_std_list), np.array(f_statistic_list) + np.array(f_statistic_std_list), alpha=0.3)
plt.xlabel("Data Size (%)")
plt.ylabel("Prob (F-statistic)")
plt.title("Prob (F-statistic) vs. Data Size (Original Scale)")
plt.legend()

# 縦軸を対数軸にした有意Fのグラフ
plt.subplot(2, 1, 2)
plt.plot(range(10, 100, 10), f_statistic_list, label="Average Prob (F-statistic)")
plt.fill_between(range(10, 100, 10), np.array(f_statistic_list) - np.array(f_statistic_std_list), np.array(f_statistic_list) + np.array(f_statistic_std_list), alpha=0.3)
plt.xlabel("Data Size (%)")
plt.ylabel("Prob (F-statistic) (Log Scale)")
plt.title("Prob (F-statistic) vs. Data Size (Log Scale)")
plt.yscale('log')  # ここで縦軸を対数軸に設定
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ３．で分かったこと（Geminiとの対話）：
#
# 問題４の最後のグラフは対数軸と通常の軸でグラフを書いたものを並べてて、見比べられるようにしたものです。これを見て分かったことを書きなさい。
#
# ---
#
# はい、承知いたしました。対数軸と通常の軸でプロットされた Prob (F-statistic) のグラフを見て分かったことを以下にまとめます。
#
# ---
#
# まとめて下さい。
#
# ---
#
# はい、問題 4 の 3 つ目のグラフ（対数軸と通常の軸でプロットされた Prob (F-statistic) のグラフ）を見て分かったことを以下にまとめます。
#
# 対数軸で見た Prob (F-statistic) のグラフから分かったこと:
#
# - 通常の軸のグラフでは、データサイズが大きくなるにつれて Prob (F-statistic) の値が急激に小さくなり、特にデータサイズが大きい領域での変化が見づらくなっていました。
# - 縦軸を対数軸にすることで、データサイズが小さい領域から大きい領域まで、Prob (F-statistic) の値の変化の傾向がより分かりやすくなりました。
# - データサイズが大きくなるにつれて、Prob (F-statistic) の値が単調に減少していく様子が明確に確認できます。これは、データサイズが大きいほど、重回帰式全体が統計的に有意であると判断できる信頼性が高まることを示しています。
# - データサイズが小さい領域での Prob (F-statistic) のばらつき（標準偏差で示される帯状の領域）も、対数軸にすることでその相対的な大きさがより把握しやすくなります。
#
# 通常の軸で見た Prob (F-statistic) のグラフから分かったこと:
#
# - データサイズが小さい領域での Prob (F-statistic) の値の絶対的な大きさとそのばらつきを把握するのに適しています。
# - データサイズが大きくなると、Prob (F-statistic) の値が非常に小さくなるため、グラフの線が X 軸に近づき、値の小さな変化やばらつきが見えにくくなります。
#
# 見比べた結果、分かったこと:
#
# - Prob (F-statistic) のように、データサイズの変化によって値が大きく、かつ非線形に変化する指標を視覚化する場合、通常の軸と対数軸の両方でプロットすることで、異なる側面からの洞察が得られます。
# - 通常の軸は値の絶対的な大きさを把握するのに役立ち、対数軸は値の相対的な変化率や、値が小さい領域での変化の傾向を捉えるのに役立ちます。
# - 特に Prob (F-statistic) の場合、対数軸で見ることで、データサイズが増えるにつれて有意性が高まる（P 値が小さくなる）傾向がより明確に視覚化されました。
#
# これらのグラフから、データサイズがモデルの統計的有意性に与える影響をより深く理解することができます。
#
# ---
#
# 対数軸で標準偏差の下限を表示することには、何か意味がありますか？下限は無限遠になってしまいませんか？
#
# ---
#
# ご質問ありがとうございます。対数軸で標準偏差の下限を表示することについてですね。おっしゃる通り、Prob (F-statistic) のような P 値は 0 から 1 の間の値をとりますが、対数軸では 0 や負の値を直接プロットすることができません。
#
# Prob (F-statistic) は確率であり、理論的には 0 になることもありますが、現実の計算結果では非常に小さな正の値になることが多いです。しかし、標準偏差を考慮して下限を計算した場合、平均値 - 標準偏差が負の値になる可能性があります。対数軸は正の値しか取れないため、この負の値はプロットできず、グラフ上では表示されないか、あるいはエラーの原因となることがあります。
#
# 今回のグラフでは、plt.fill_between 関数が使用されています。この関数は指定された範囲を描画しますが、対数軸の場合、負の値やゼロは適切に処理されないため、下限が計算上負になる場合は、その部分の描画がスキップされるか、エラーが発生します。試行数を 100 回に増やしたことで、特にデータサイズが大きいところでは Prob (F-statistic) の平均値が非常に小さくなり、標準偏差を引くと負の値になるケースが増えたため、下限の帯が表示されない、あるいは無限遠のように見えるという状況が発生したと考えられます。
#
# したがって、対数軸で標準偏差の帯を表示する場合、特に平均値が 0 に近い小さな値をとる場合は、下限が正確に表示されない、あるいは技術的な制約により表示できない可能性があることを理解しておく必要があります。これは、ばらつきの解釈に対しても注意が必要であることを意味します。
#
# この点を踏まえると、対数軸でばらつきを示す際には、標準偏差ではなく、パーセンタイル（例えば 25 パーセンタイルと 75 パーセンタイル）など、常に正の値をとる範囲を示す指標を用いる方が、グラフの解釈がより適切になる場合があります。
#
# ---
#
# なるほど。通常軸のグラフにおいても、「平均値ー標準偏差」が負の値になっているのは、気持ち悪いですよね。通常軸、対数軸を問わず、平均値周りに対称でない分布を、「平均値プラスマイナス標準偏差」の帯で表示しようとしたことが、そもそも、間違いだったということでしょうか？その意味で、 25 パーセンタイルと 75 パーセンタイルをグラフ化するのが正しい可視化だ、ということでしょうか？
#
# ---
#
# はい、おっしゃる通りです。「平均値 ± 標準偏差」は、データが正規分布に近い、つまり平均値を中心に左右対称に分布している場合に、データのばらつきを示すのに適した方法です。
#
# 今回の Prob (F-statistic) のように、値が 0 に近づくにつれて分布が歪む（非対称になる）場合、特にデータサイズが大きくなるにつれて値が非常に小さくなる傾向があるため、「平均値 - 標準偏差」が負の値になることがありえます。これは、実際の Prob (F-statistic) の値が負にならないという性質と矛盾するため、「平均値 ± 標準偏差」でばらつきを示すことが適切ではないことを示しています。
#
# このような非対称な分布の場合、25 パーセンタイルと 75 パーセンタイル（これらはデータの中心 50%が含まれる範囲を示し、箱ひげ図の箱に対応します）や、より広い範囲を示す 10 パーセンタイルと 90 パーセンタイルなど、パーセンタイルを用いる方が、データの実際の分布に基づいたばらつきをより正確に、かつ直感的に把握できます。これらのパーセンタイルはデータの実際の値から計算されるため、Prob (F-statistic) のような非負の値をとる指標に対しては、常に適切な範囲（0 以上の値）を示します。
#
# したがって、非対称な分布のばらつきを可視化する際には、パーセンタイルを使用する方がより「正しい」または適切であると言えます。今回のケースでは、データサイズが小さいところでのばらつきが大きいことや、大きいデータサイズでは値が 0 に近づく傾向があることを示すために、パーセンタイルでの可視化を試みるのは非常に良いアプローチだと思います。

# %%
# prompt: 問題３のProb (F-statistic) の可視化グラフを、以下のように修正する。平均値プラスマイナス標準偏差で可視化するのではなく、25 パーセンタイルと 75 パーセンタイルで可視化する。縦軸について、通常の軸の場合と対数軸の場合を並べて示して、見比べることができるようにする。

# 関数の定義：adjusted R^2 と F-statistic を 指定したデータサイズに対して算出する
def evaluate_model_percentiles(data_size, num_trials=100):
    # 結果を格納するリストの初期化
    r2_adjusted_trial = []
    f_statistic_trial = []

    # 指定回数の試行ループ
    for _ in range(num_trials):
        # 学習セットとテストセットに、指定したサイズでランダム分割する（学習セットだけ使用）
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=data_size)

        # Add a constant term to the independent variables
        X_train_c = sm.add_constant(X_train)

        # OLSモデルの構築とフィット
        ols_model = sm.OLS(Y_train, X_train_c)
        results = ols_model.fit()

        # Append the results of this trial
        r2_adjusted_trial.append(results.rsquared_adj)
        f_statistic_trial.append(results.f_pvalue)

    # 結果をnumpy配列に変換
    r2_adjusted_trial = np.array(r2_adjusted_trial)
    f_statistic_trial = np.array(f_statistic_trial)

    # 25パーセンタイルと75パーセンタイルを算出
    r2_adjusted_q1 = np.percentile(r2_adjusted_trial, 25)
    r2_adjusted_q3 = np.percentile(r2_adjusted_trial, 75)
    f_statistic_q1 = np.percentile(f_statistic_trial, 25)
    f_statistic_q3 = np.percentile(f_statistic_trial, 75)

    # 平均値も算出しておく（参考用）
    r2_adjusted_mean = np.mean(r2_adjusted_trial)
    f_statistic_mean = np.mean(f_statistic_trial)


    # パーセンタイルと平均値を返す
    return (r2_adjusted_mean, r2_adjusted_q1, r2_adjusted_q3,
            f_statistic_mean, f_statistic_q1, f_statistic_q3)

# 結果を格納するリストの初期化
r2_adjusted_mean_list = []
r2_adjusted_q1_list = []
r2_adjusted_q3_list = []
f_statistic_mean_list = []
f_statistic_q1_list = []
f_statistic_q3_list = []

# いろいろなデータサイズでループ：100%は分割にならないので、90%まで実施。
for data_size in range(10, 100, 10):
    # Adjusted R^2 と F-statistic のパーセンタイルと平均を算出 (100回試行)
    (r2_adjusted_mean, r2_adjusted_q1, r2_adjusted_q3,
     f_statistic_mean, f_statistic_q1, f_statistic_q3) = evaluate_model_percentiles(data_size / 100, num_trials=100)

    # 結果をリストに追加
    r2_adjusted_mean_list.append(r2_adjusted_mean)
    r2_adjusted_q1_list.append(r2_adjusted_q1)
    r2_adjusted_q3_list.append(r2_adjusted_q3)
    f_statistic_mean_list.append(f_statistic_mean)
    f_statistic_q1_list.append(f_statistic_q1)
    f_statistic_q3_list.append(f_statistic_q3)

# グラフで可視化 (Prob (F-statistic) の25, 75パーセンタイル)
plt.figure(figsize=(12, 6))

# 通常の軸のProb (F-statistic) のグラフ
plt.subplot(1, 2, 1)
plt.plot(range(10, 100, 10), f_statistic_mean_list, label="Average Prob (F-statistic)", color='blue')
plt.fill_between(range(10, 100, 10), f_statistic_q1_list, f_statistic_q3_list, alpha=0.3, color='blue', label="25th to 75th Percentile")
plt.xlabel("Data Size (%)")
plt.ylabel("Prob (F-statistic)")
plt.title("Prob (F-statistic) vs. Data Size (Original Scale)")
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)


# 縦軸を対数軸にしたProb (F-statistic) のグラフ
plt.subplot(1, 2, 2)
plt.plot(range(10, 100, 10), f_statistic_mean_list, label="Average Prob (F-statistic)", color='blue')
plt.fill_between(range(10, 100, 10), f_statistic_q1_list, f_statistic_q3_list, alpha=0.3, color='blue', label="25th to 75th Percentile")
plt.xlabel("Data Size (%)")
plt.ylabel("Prob (F-statistic) (Log Scale)")
plt.title("Prob (F-statistic) vs. Data Size (Log Scale)")
plt.yscale('log')  # ここで縦軸を対数軸に設定
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)


plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)

# %% [markdown]
# 平均値が25パーセンタイルから75パーセンタイルの範囲から外れる分布を想像するのが難しいので、データサイズごとにヒストグラムを作成してみよう。

# %%
# prompt: データサイズが30％の場合について、100試行におけるProb (F-statistic)の値のヒストグラムを作成。

# データサイズが30％の場合について、100試行におけるProb (F-statistic)の値のヒストグラムを作成
data_size = 0.3  # 30%のデータサイズ
num_trials = 100 # 試行回数

f_statistic_trials = []

for _ in range(num_trials):
    # 学習セットとテストセットに、指定したサイズでランダム分割する（学習セットだけ使用）
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=data_size)

    # Add a constant term to the independent variables
    X_train_c = sm.add_constant(X_train)

    # OLSモデルの構築とフィット
    ols_model = sm.OLS(Y_train, X_train_c)
    results = ols_model.fit()

    # Prob (F-statistic)をリストに追加
    f_statistic_trials.append(results.f_pvalue)

# ヒストグラムを作成
plt.figure(figsize=(8, 6))
plt.hist(f_statistic_trials, bins=50, edgecolor='black')
plt.xlabel("Prob (F-statistic)")
plt.ylabel("Frequency")
plt.title(f"Histogram of Prob (F-statistic) for Data Size {int(data_size*100)}% ({num_trials} Trials)")
plt.grid(True)
plt.show()

# %% [markdown]
# 「5%有意水準で統計的に有意であると判断される割合」が100試行中何回あるか、という指標が、データサイズにより、どう変化するか、という可視化が良さそうな気がしてきた。
